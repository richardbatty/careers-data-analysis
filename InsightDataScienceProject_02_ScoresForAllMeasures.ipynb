# %% [markdown]
# # Insight Data Science Consulting Project: 80,000 hours - Chapter 2

# %% [markdown]
# Note: this is a part of a consulting project with [80,000 hours](https://80000hours.org/).

# %% [markdown]
# ## Stage 1: Ask a question
#
# My objective is to rank skills (and possibly knowledge, tools & tech) based on how valuable they are. The skills are listed by US Department of Labor [here](https://www.onetonline.org/find/descriptor/browse/Skills/2.B.1/).
#
# There is no performance measure for this rank yet since it is subjective. Yet in the future, one can create a poll to rate pairwise.

# %% [markdown]
# ## Stage 2: Set the environment up and get data
#
# First, set up a directory for data and link it to this workplace. Download data into your choice of directory.

# %%
#Set up the environment
import pandas as pd                        #Pandas
import numpy as np                         #Numpy
import pycurl                              #For saving file from url
import os                                  #For checking if a file exists
from pandas.parser import CParserError     #For checking if a file contains a set of values
import matplotlib.pyplot as plt            #For plotting
import matplotlib
# %matplotlib inline

#Some machine learning tools
from sklearn.linear_model import LassoCV, LassoLarsCV, LinearRegression
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.neural_network import MLPRegressor
from sklearn.model_selection import StratifiedKFold
from sklearn.feature_selection import RFECV, f_regression

# Set up data directory
DataDir = "C:/Users/Admin/Desktop/Insight/data/"

# %% [markdown]
# ## Stage 3: Feature exploration
#
# In this stage, we look into data. Let's focus on Skills for now.

# %% [markdown]
# ### Stage 3.1: Skills

# %%
filename = "dSkill.csv"
dSkill = pd.read_csv(DataDir+filename)
dSkill = dSkill.drop('Unnamed: 0', 1)

# %%
dSkill.shape
# Out:
# (953, 36)

# %%
dSkill[:5]
# Out:
#      SOC code  Active Learning  Active Listening  Complex Problem Solving  \
# 0  11-1011.00               75                78                       85
# 1  11-1011.03               63                72                       75
# 2  11-1021.00               63                75                       63
# 3  11-2011.00               56                75                       63
# 4  11-2021.00               72                72                       66
#
#    Coordination  Critical Thinking  Equipment Maintenance  \
# 0            81                 85                      0
# 1            66                 75                      0
# 2            75                 72                      0
# 3            63                 69                      0
# 4            63                 72                      0
#
#    Equipment Selection  Installation  Instructing   ...     Science  \
# 0                    3             0           53   ...          22
# 1                    3             0           56   ...          19
# 2                    0             0           53   ...          22
# 3                    6             0           47   ...          13
# 4                    0             0           50   ...          19
#
#    Service Orientation  Social Perceptiveness  Speaking  Systems Analysis  \
# 0                   53                     81        85                78
# 1                   56                     69        75                66
# 2                   56                     75        75                50
# 3                   53                     75        75                53
# 4                   53                     72        72                56
#
#    Systems Evaluation  Technology Design  Time Management  Troubleshooting  \
# 0                  78                 19               75                0
# 1                  66                 16               60                3
# 2                  50                 22               69               25
# 3                  50                 16               72                3
# 4                  63                 19               63                0
#
#    Writing
# 0       75
# 1       72
# 2       56
# 3       69
# 4       56
#
# [5 rows x 36 columns]

# %% [markdown]
# Let's create a color map.

# %%
fig = plt.figure(figsize=(10,5))
ax1  = fig.add_subplot(111)
plt.xlabel("Occupation")
plt.ylabel("Skill")
plt.imshow(dSkill.set_index('SOC code').T, cmap='hot', interpolation='nearest',aspect='auto')
plt.colorbar();

# %%
#Correlation matrix
CorrMatrix = dSkill.set_index('SOC code').corr()
fig = plt.figure(figsize=(8,6))
ax1  = fig.add_subplot(111)
#plt.xlabel("Occupation")
#plt.ylabel("Skill + Knowledge")
plt.imshow(CorrMatrix.T, cmap='copper', interpolation='nearest',aspect='auto')
plt.colorbar();

# %%
for i in range(1,len(CorrMatrix)):
    for j in range(0,i):
        if CorrMatrix.loc[CorrMatrix.index[j],CorrMatrix.columns[i]]>0.9:
            print [CorrMatrix.index[j],CorrMatrix.columns[i]]
# Out:
# ['Operation Monitoring', 'Operation and Control']
# ['Equipment Maintenance', 'Repairing']
# ['Equipment Selection', 'Repairing']
# ['Systems Analysis', 'Systems Evaluation']
# ['Reading Comprehension', 'Writing']

# %% [markdown]
# ### Stage 3.2: Knowledge

# %%
# filename = "dKnowledge.csv"
# dKnowledge = pd.read_csv(DataDir+filename)
# dKnowledge = dKnowledge.drop('Unnamed: 0', 1)

# %%
# dKnowledge.shape

# %%
# dKnowledge[:5]

# %%
# fig = plt.figure(figsize=(10,5))
# ax1  = fig.add_subplot(111)
# plt.xlabel("Occupation")
# plt.ylabel("Knowledge")
# plt.imshow(dKnowledge.set_index('SOC code').T, cmap='cool', interpolation='nearest',aspect='auto')
# plt.colorbar();

# %%
# #Correlation matrix
# CorrMatrix = dKnowledge.set_index('SOC code').corr()
# fig = plt.figure(figsize=(8,6))
# ax1  = fig.add_subplot(111)
# #plt.xlabel("Occupation")
# #plt.ylabel("Skill + Knowledge")
# plt.imshow(CorrMatrix.T, cmap='cool', interpolation='nearest',aspect='auto')
# plt.colorbar();

# %%
# for i in range(1,len(CorrMatrix)):
#     for j in range(0,i):
#         if CorrMatrix.loc[CorrMatrix.index[j],CorrMatrix.columns[i]]>0.9:
#             print [CorrMatrix.index[j],CorrMatrix.columns[i]]

# %% [markdown]
# ### Stage 3.3: Outputs

# %% [markdown]
# In this round, we will focus on transferability. So, we will use only job openings.

# %%
filename = "dJobOpenings.csv"
dJobOpenings = pd.read_csv(DataDir+filename)
dJobOpenings = dJobOpenings.drop('Unnamed: 0', 1)

# %%
# fig = plt.figure(figsize=(14,1))
# ax1  = fig.add_subplot(111)
# plt.xlabel("Occupation")
# plt.ylabel("Job Openings")
# plt.gca().yaxis.set_major_locator(plt.NullLocator())
# plt.imshow(dJobOpenings.set_index('SOC code').T, cmap='BuGn', interpolation='nearest',aspect='auto');

# %%
filename = "dJobZone.csv"
dJobZone = pd.read_csv(DataDir+filename)
dJobZone = dJobZone.drop('Unnamed: 0', 1)

# %%
filename = "dRiskOfAutomation.csv"
dRiskOfAutomation = pd.read_csv(DataDir+filename)
dRiskOfAutomation = dRiskOfAutomation.drop('Unnamed: 0', 1)

# %%
filename = "dLevelOfCompetition.csv"
dLevelOfCompetition = pd.read_csv(DataDir+filename)
dLevelOfCompetition = dLevelOfCompetition.drop('Unnamed: 0', 1)

# %%
filename = "dWage_BLS.csv"
dWage_BLS = pd.read_csv(DataDir+filename)
dWage_BLS = dWage_BLS.drop('Unnamed: 0', 1)

# %%
filename = "dJobSatisfaction_GSS.csv"
dJobSatisfaction_GSS = pd.read_csv(DataDir+filename)
dJobSatisfaction_GSS = dJobSatisfaction_GSS.drop('Unnamed: 0', 1)

#in order to run regression, we need to group by occupations first
#summarize by occupations
dJobSatisfaction_GSS = dJobSatisfaction_GSS.groupby(['SOC code']).mean().reset_index()

# %%
filename = "dPayScale.csv"
dJobSatisfaction_PayScale = pd.read_csv(DataDir+filename)
dJobSatisfaction_PayScale = dJobSatisfaction_PayScale.drop('Unnamed: 0', 1)
dJobSatisfaction_PayScale = dJobSatisfaction_PayScale.drop(['Median Pay', 'High Meaning'], axis = 1)
dJobSatisfaction_PayScale.rename(columns={'High Satisfaction':'JobSatisfaction_PayScale'}, inplace=True)

# %%
filename = "dPayScale.csv" 
dWage_PayScale = pd.read_csv(DataDir+filename)
dWage_PayScale = dWage_PayScale.drop('Unnamed: 0', 1)
dWage_PayScale = dWage_PayScale.drop(['High Satisfaction', 'High Meaning'], axis = 1)
dWage_PayScale.rename(columns={'Median Pay':'Wage_PayScale'}, inplace=True)

# %%
filename = "dPayScale.csv" 
dJobMeaning_PayScale = pd.read_csv(DataDir+filename)
dJobMeaning_PayScale = dJobMeaning_PayScale.drop('Unnamed: 0', 1)
dJobMeaning_PayScale = dJobMeaning_PayScale.drop(['High Satisfaction', 'Median Pay'], axis = 1)
dJobMeaning_PayScale.rename(columns={'High Meaning':'JobMeaning_PayScale'}, inplace=True)

# %% [markdown]
# ## Stage 4: Score for all measures

# %% [markdown]
# At this point, we are going to develop a score for each measure. Transferabiltiy is a unique one: how often a skill appears across different occupations weighed with job openings.

# %%
#Define what you want to work on first.
interest = 'Skill'
#interest = 'Knowledge'

# %%
dSummary = pd.DataFrame()

# %%
exec('d = d'+interest)
d.loc[:,'SOC code'] = d['SOC code'].map(lambda x: x[0:7])
d = d.groupby(['SOC code']).mean()
d = d.reset_index()
dbasis = d

# %%
#merge dJobOpenings and skills/knowledge
dbig = dJobOpenings.merge(dbasis, left_on='SOC code',  right_on='SOC code', how ='left')
dbig = dbig.dropna()
dbig = dbig.set_index('SOC code')

for i in range(1,len(dbig.columns)):
    for j in dbig.index:
        dbig.loc[j,dbig.columns[i]] = dbig.loc[j,dbig.columns[i]]*dbig.loc[j,'JobOpenings']

dbig = dbig.drop('JobOpenings',axis=1)

d = pd.DataFrame(dbig.sum(axis =0),columns = ['value'])
mean = d['value'].mean()
d['ratio'] = d['value']/mean

np.min(d['ratio']), np.max(d['ratio'])
# Out:
# (0.10845285341582284, 1.769503857627116)

# %%
dSummary['Transferability'] = d['ratio'] -1

# %% [markdown]
# This creates a score telling how much a skill can make a difference relative to the mean value.
#
# Now let's move on to other measures. They are related to linear regression.

# %%
filename = "dSkill.csv"
dSkill = pd.read_csv(DataDir+filename)
dSkill = dSkill.drop('Unnamed: 0', 1)

# filename = "dKnowledge.csv"
# dKnowledge = pd.read_csv(DataDir+filename)
# dKnowledge = dKnowledge.drop('Unnamed: 0', 1)

# %%
def regression(X_train, y_train):    
    # Create the RFE object and compute a cross-validated score.
    LR = LinearRegression()
    rfecv = RFECV(estimator=LR, step=1, cv=StratifiedKFold(3),
                  scoring='r2')
    rfecv.fit(X_train, y_train)
    _, pvalue = f_regression(X_train, y_train)

    l1 = dbasis.set_index('SOC code').columns[rfecv.support_]
    l2 = rfecv.estimator_.coef_

    #Compare with vanilla OLS and LassoCV
    model_ols = LinearRegression().fit(X_train, y_train)
    model_lassocv = LassoCV(cv=3).fit(X_train, y_train)

    output = [model_ols.score(X_train,y_train), model_lassocv.score(X_train,y_train), 
              rfecv.estimator_.score(X_train[l1],y_train), 
              model_ols.intercept_, model_lassocv.intercept_,  rfecv.estimator_.intercept_,
     np.sum([i!=0 for i in model_ols.coef_]), np.sum([i!=0 for i in model_lassocv.coef_]), len(l1)]
    return model_ols, model_lassocv, l1, l2, pvalue, output;
    

def create_CoefTable(model_ols, model_lassocv, l1, l2, pvalue):
    CoefTable = pd.DataFrame(columns = ['coef_ols','coef_lassocv','coef_ols_rfe'])
    CoefTable['index'] = dbasis.set_index('SOC code').columns
    CoefTable = CoefTable.set_index('index')
    CoefTable['coef_ols'] = model_ols.coef_
    CoefTable['coef_lassocv'] = model_lassocv.coef_
    CoefTable['coef_ols_rfe'] = 0
    for i in range(0,len(l1)):
        CoefTable.loc[l1[i],'coef_ols_rfe'] = l2[i]
    CoefTable['coef_ols'] = CoefTable['coef_ols']*(pvalue<0.05)
    CoefTable['coef_lassocv'] = CoefTable['coef_lassocv']*(pvalue<0.05)
    CoefTable['coef_ols_rfe'] = CoefTable['coef_ols_rfe']*(pvalue<0.05)
        
    return CoefTable;
    
def create_IndexTable(CoefTable, n0):
    IndexTable = pd.DataFrame(CoefTable)

    IndexTable['ols'] = IndexTable['coef_ols']/n0*100
    IndexTable['lassocv'] = IndexTable['coef_lassocv']/n0*100
    IndexTable['ols_rfe'] = IndexTable['coef_ols_rfe']/n0*100
    
    IndexTable['score'] = IndexTable['ols']+IndexTable['lassocv']+IndexTable['ols_rfe']
    IndexTable['score'] = IndexTable['score']/3
    return IndexTable;

# %%
#Keep iterating through all measures

#These have SOC codes with decimals
#keyword = 'JobZone'
#keyword = 'LevelOfCompetition'
#keyword = 'JobSatisfaction_PayScale'
#keyword = 'JobMeaning_PayScale'
#keyword = 'Wage_PayScale'

#These have SOC codes without decimals
#keyword = 'Wage_BLS'
keyword = 'RiskOfAutomation'
#keyword = 'JobSatisfaction_GSS'

# %%
#These have SOC codes with decimals
if keyword in ['JobZone','LevelOfCompetition','JobSatisfaction_PayScale','JobMeaning_PayScale','Wage_PayScale']:
    exec('dbasis = d' + interest) 
    
#These have SOC codes without decimals
if keyword in ['Wage_BLS', 'RiskOfAutomation', 'JobSatisfaction_GSS']:
    exec('d = d' + interest) 
    d.loc[:,'SOC code'] = d['SOC code'].map(lambda x: x[0:7])
    d = d.groupby(['SOC code']).mean()
    d = d.reset_index()
    dbasis = d

# %%
exec("dbig = d"+keyword+".merge(dbasis, left_on='SOC code',  right_on='SOC code', how ='left')")

# %%
dbig = dbig.dropna()
dbig = dbig.set_index('SOC code')
len(dbig), len(dbig.columns)
# Out:
# (684, 36)

# %%
dbig = dbig.drop_duplicates()
len(dbig), len(dbig.columns)
# Out:
# (684, 36)

# %%
# There is no real test/train here. Just explanatory factor.
X_train = dbig.drop(keyword, axis=1)
y_train = dbig[keyword]

# %%
plt.plot(X_train['Mathematics'], y_train,'.')

# %%
model_ols = LinearRegression().fit(np.matrix(X_train['Mathematics']).T, y_train)
model_ols.coef_
# Out:
# array([-0.00726546])

# %%
model_ols, model_lassocv, l1, l2, pvalue, output = regression(X_train, y_train)
print output
# Out:
# [0.66078437549538238, 0.64992654009937278, 0.65996168104270847, 1.5314444821984439, 1.4760933994698919, 1.5254176092369049, 35, 22, 24]

# %%
CoefTable = create_CoefTable(model_ols, model_lassocv, l1, l2, pvalue)
IndexTable = create_IndexTable(CoefTable, np.mean(dbig[keyword]))
#pd.concat([IndexTable.sort_values(by='score')[:5],IndexTable.sort_values(by='score')[-5:]])
IndexTable.sort_values(by='score')
# Out:
#                                        coef_ols  coef_lassocv  coef_ols_rfe  \
# index
# Critical Thinking                 -7.921303e-03     -0.005275     -0.008292
# Technology Design                 -7.330712e-03     -0.006261     -0.007541
# Social Perceptiveness             -6.034554e-03     -0.005268     -0.005977
# Management of Material Resources  -5.839166e-03     -0.003069     -0.005944
# Systems Evaluation                -4.532430e-03     -0.003551     -0.004731
# Instructing                       -3.302813e-03     -0.002900     -0.003308
# Science                           -2.681262e-03     -0.003192     -0.002820
# Monitoring                        -2.982116e-03     -0.002379     -0.003134
# Operations Analysis               -2.211719e-03     -0.002506     -0.002364
# Active Learning                   -2.667350e-03     -0.001332     -0.002614
# Operation and Control             -2.658229e-03     -0.001158     -0.002784
# Coordination                      -1.509283e-03     -0.001450     -0.001425
# Equipment Maintenance             -2.162661e-03     -0.000000     -0.002084
# Active Listening                  -1.506006e-03     -0.000000     -0.001689
# Programming                       -1.117905e-03     -0.000243     -0.001224
# Complex Problem Solving           -1.117885e-03     -0.000000      0.000000
# Learning Strategies               -2.433351e-05     -0.000926      0.000000
# Speaking                          -7.419377e-04     -0.000000      0.000000
# Equipment Selection               -6.603414e-04     -0.000064      0.000000
# Systems Analysis                  -5.697012e-04     -0.000024      0.000000
# Quality Control Analysis          -3.798532e-04      0.000000      0.000000
# Service Orientation               -4.596377e-08     -0.000000      0.000000
# Management of Personnel Resources  6.022806e-05     -0.000000      0.000000
# Installation                       5.516070e-04      0.000000      0.000000
# Time Management                    7.388045e-04      0.000000      0.000000
# Writing                            8.851407e-04      0.000000      0.000000
# Persuasion                         1.190460e-03      0.000000      0.000949
# Judgment and Decision Making       1.817131e-03     -0.000000      0.001482
# Negotiation                        1.819628e-03      0.000257      0.001999
# Management of Financial Resources  2.189959e-03      0.000000      0.002263
# Troubleshooting                    2.622574e-03      0.001005      0.002517
# Repairing                          2.892550e-03      0.001161      0.002605
# Operation Monitoring               5.546886e-03      0.003403      0.005460
# Reading Comprehension              5.719841e-03      0.003281      0.006310
# Mathematics                        6.097445e-03      0.005359      0.005980
#
#                                         ols   lassocv   ols_rfe     score
# index
# Critical Thinking                 -1.467360 -0.977115 -1.536116 -1.326864
# Technology Design                 -1.357957 -1.159883 -1.396858 -1.304899
# Social Perceptiveness             -1.117854 -0.975863 -1.107244 -1.066987
# Management of Material Resources  -1.081660 -0.568549 -1.101080 -0.917096
# Systems Evaluation                -0.839597 -0.657743 -0.876300 -0.791213
# Instructing                       -0.611820 -0.537155 -0.612834 -0.587270
# Science                           -0.496683 -0.591325 -0.522311 -0.536773
# Monitoring                        -0.552414 -0.440735 -0.580640 -0.524596
# Operations Analysis               -0.409704 -0.464272 -0.437939 -0.437305
# Active Learning                   -0.494106 -0.246687 -0.484263 -0.408352
# Operation and Control             -0.492416 -0.214522 -0.515667 -0.407535
# Coordination                      -0.279583 -0.268533 -0.264006 -0.270707
# Equipment Maintenance             -0.400616 -0.000000 -0.386026 -0.262214
# Active Listening                  -0.278976 -0.000000 -0.312814 -0.197263
# Programming                       -0.207083 -0.044972 -0.226714 -0.159590
# Complex Problem Solving           -0.207079 -0.000000  0.000000 -0.069026
# Learning Strategies               -0.004508 -0.171521  0.000000 -0.058676
# Speaking                          -0.137438 -0.000000  0.000000 -0.045813
# Equipment Selection               -0.122323 -0.011873  0.000000 -0.044732
# Systems Analysis                  -0.105533 -0.004451  0.000000 -0.036661
# Quality Control Analysis          -0.070365  0.000000  0.000000 -0.023455
# Service Orientation               -0.000009 -0.000000  0.000000 -0.000003
# Management of Personnel Resources  0.011157 -0.000000  0.000000  0.003719
# Installation                       0.102181  0.000000  0.000000  0.034060
# Time Management                    0.136858  0.000000  0.000000  0.045619
# Writing                            0.163965  0.000000  0.000000  0.054655
# Persuasion                         0.220523  0.000000  0.175771  0.132098
# Judgment and Decision Making       0.336609 -0.000000  0.274449  0.203686
# Negotiation                        0.337072  0.047699  0.370252  0.251674
# Management of Financial Resources  0.405673  0.000000  0.419174  0.274949
# Troubleshooting                    0.485811  0.186247  0.466307  0.379455
# Repairing                          0.535822  0.215086  0.482581  0.411163
# Operation Monitoring               1.027517  0.630317  1.011359  0.889731
# Reading Comprehension              1.059556  0.607790  1.168795  0.945381
# Mathematics                        1.129504  0.992647  1.107836  1.076662

# %%
dSummary[keyword] = IndexTable['score']

# %%
dSummary
# Out:
#                                    Transferability   JobZone  \
# Active Learning                           0.326332  0.379059
# Active Listening                          0.769504 -0.094298
# Complex Problem Solving                   0.347553  0.141818
# Coordination                              0.490399 -0.219109
# Critical Thinking                         0.593723  0.420011
# Equipment Maintenance                    -0.711690  0.043375
# Equipment Selection                      -0.688951  0.024488
# Installation                             -0.891547  0.125590
# Instructing                               0.223327  0.256220
# Judgment and Decision Making              0.443466  0.375683
# Learning Strategies                       0.144138 -0.016679
# Management of Financial Resources        -0.457487  0.098905
# Management of Material Resources         -0.384720  0.187712
# Management of Personnel Resources         0.075065 -0.228090
# Mathematics                              -0.002070 -0.245005
# Monitoring                                0.517347 -0.139119
# Negotiation                               0.153014 -0.263144
# Operation Monitoring                     -0.113049 -0.135297
# Operation and Control                    -0.342179 -0.088246
# Operations Analysis                      -0.439431  0.124523
# Persuasion                                0.241689 -0.009907
# Programming                              -0.697158  0.005544
# Quality Control Analysis                 -0.221599 -0.175359
# Reading Comprehension                     0.564160  0.512555
# Repairing                                -0.732443  0.007862
# Science                                  -0.591761  0.329957
# Service Orientation                       0.475785 -0.153915
# Social Perceptiveness                     0.549760  0.252305
# Speaking                                  0.721148 -0.146102
# Systems Analysis                         -0.008886  0.223440
# Systems Evaluation                       -0.026384 -0.001314
# Technology Design                        -0.618583  0.180032
# Time Management                           0.410188  0.063163
# Troubleshooting                          -0.471752 -0.213344
# Writing                                   0.353093  0.299653
#
#                                    LevelOfCompetition  \
# Active Learning                              0.573836
# Active Listening                            -0.070283
# Complex Problem Solving                      0.089406
# Coordination                                 0.065650
# Critical Thinking                            0.042740
# Equipment Maintenance                        0.034381
# Equipment Selection                          0.000000
# Installation                                 0.000000
# Instructing                                  0.054521
# Judgment and Decision Making                 0.363652
# Learning Strategies                         -0.161045
# Management of Financial Resources            0.129754
# Management of Material Resources            -0.036428
# Management of Personnel Resources            0.039140
# Mathematics                                  0.022522
# Monitoring                                  -0.032992
# Negotiation                                 -0.054323
# Operation Monitoring                        -0.068570
# Operation and Control                        0.017738
# Operations Analysis                          0.108024
# Persuasion                                   0.658126
# Programming                                 -0.036878
# Quality Control Analysis                     0.000000
# Reading Comprehension                        0.007650
# Repairing                                   -0.051208
# Science                                     -0.015519
# Service Orientation                         -0.381756
# Social Perceptiveness                       -0.317344
# Speaking                                     0.218737
# Systems Analysis                            -0.046613
# Systems Evaluation                          -0.058850
# Technology Design                            0.037177
# Time Management                              0.009642
# Troubleshooting                             -0.016376
# Writing                                     -0.218140
#
#                                    JobSatisfaction_PayScale  \
# Active Learning                                    0.223553
# Active Listening                                  -0.033264
# Complex Problem Solving                           -0.013635
# Coordination                                       0.006922
# Critical Thinking                                  0.062990
# Equipment Maintenance                              0.013119
# Equipment Selection                               -0.027021
# Installation                                       0.000000
# Instructing                                        0.035416
# Judgment and Decision Making                       0.100377
# Learning Strategies                                0.044085
# Management of Financial Resources                 -0.021898
# Management of Material Resources                   0.010063
# Management of Personnel Resources                  0.065481
# Mathematics                                       -0.023420
# Monitoring                                        -0.068396
# Negotiation                                       -0.033793
# Operation Monitoring                               0.010909
# Operation and Control                             -0.021645
# Operations Analysis                               -0.013258
# Persuasion                                        -0.000646
# Programming                                       -0.030576
# Quality Control Analysis                           0.000000
# Reading Comprehension                              0.185494
# Repairing                                         -0.002857
# Science                                            0.003017
# Service Orientation                               -0.014013
# Social Perceptiveness                              0.115945
# Speaking                                          -0.024619
# Systems Analysis                                   0.033333
# Systems Evaluation                                -0.052443
# Technology Design                                  0.047894
# Time Management                                   -0.003578
# Troubleshooting                                    0.023208
# Writing                                            0.099618
#
#                                    JobMeaning_PayScale  Wage_PayScale  \
# Active Learning                              -0.049714       0.112420
# Active Listening                              0.040298      -0.313650
# Complex Problem Solving                       0.001371       0.946684
# Coordination                                 -0.097550      -0.078285
# Critical Thinking                             0.069748       0.974061
# Equipment Maintenance                         0.027825      -0.242051
# Equipment Selection                           0.000000       0.000000
# Installation                                  0.000000       0.000000
# Instructing                                   0.078028      -0.235519
# Judgment and Decision Making                  0.143790       1.461735
# Learning Strategies                           0.672303      -0.113815
# Management of Financial Resources            -0.000000       0.094887
# Management of Material Resources              0.269937      -0.030520
# Management of Personnel Resources             0.056954       0.014336
# Mathematics                                  -0.000000       0.032263
# Monitoring                                   -0.074090       0.153694
# Negotiation                                  -0.450249      -0.198494
# Operation Monitoring                          0.000000       0.000000
# Operation and Control                         0.043774       0.000000
# Operations Analysis                          -0.222899       0.001114
# Persuasion                                   -0.206143       0.087258
# Programming                                  -0.000000      -0.059729
# Quality Control Analysis                      0.000000       0.000000
# Reading Comprehension                         0.332447       0.085830
# Repairing                                     0.033753      -0.204062
# Science                                       0.641146       0.465752
# Service Orientation                           0.304834      -0.002006
# Social Perceptiveness                         0.606856       0.214177
# Speaking                                     -0.022966      -0.216791
# Systems Analysis                             -0.026063      -0.244634
# Systems Evaluation                            0.005172      -0.100372
# Technology Design                             0.308119      -0.238767
# Time Management                               0.074091       0.071302
# Troubleshooting                               0.000000       0.000000
# Writing                                       0.006762       0.082929
#
#                                    Wage_BLS  RiskOfAutomation  \
# Active Learning                    0.294334         -0.408352
# Active Listening                  -0.133484         -0.197263
# Complex Problem Solving            0.972528         -0.069026
# Coordination                       0.002584         -0.270707
# Critical Thinking                  0.731563         -1.326864
# Equipment Maintenance              0.049473         -0.262214
# Equipment Selection               -0.132703         -0.044732
# Installation                       0.004338          0.034060
# Instructing                        0.024147         -0.587270
# Judgment and Decision Making       0.554798          0.203686
# Learning Strategies               -0.368408         -0.058676
# Management of Financial Resources  0.800687          0.274949
# Management of Material Resources  -0.506401         -0.917096
# Management of Personnel Resources  0.243709          0.003719
# Mathematics                       -0.031498          1.076662
# Monitoring                         0.195251         -0.524596
# Negotiation                       -0.096067          0.251674
# Operation Monitoring               0.069007          0.889731
# Operation and Control             -0.072377         -0.407535
# Operations Analysis                0.147748         -0.437305
# Persuasion                        -0.013401          0.132098
# Programming                       -0.006682         -0.159590
# Quality Control Analysis          -0.000000         -0.023455
# Reading Comprehension              0.250609          0.945381
# Repairing                         -0.085899          0.411163
# Science                            0.407588         -0.536773
# Service Orientation               -0.484083         -0.000003
# Social Perceptiveness              0.035851         -1.066987
# Speaking                           0.053576         -0.045813
# Systems Analysis                  -0.000135         -0.036661
# Systems Evaluation                 0.061132         -0.791213
# Technology Design                  0.242475         -1.304899
# Time Management                    0.053839          0.045619
# Troubleshooting                    0.132790          0.379455
# Writing                           -0.091652          0.054655
#
#                                    JobSatisfaction_GSS
# Active Learning                               0.275881
# Active Listening                              0.063492
# Complex Problem Solving                       0.037434
# Coordination                                  0.057620
# Critical Thinking                             0.011320
# Equipment Maintenance                         0.000000
# Equipment Selection                           0.000000
# Installation                                  0.000000
# Instructing                                  -0.015610
# Judgment and Decision Making                  0.036577
# Learning Strategies                           0.028754
# Management of Financial Resources            -0.016987
# Management of Material Resources              0.161991
# Management of Personnel Resources            -0.058394
# Mathematics                                   0.000000
# Monitoring                                   -0.016454
# Negotiation                                  -0.046028
# Operation Monitoring                          0.000000
# Operation and Control                         0.000000
# Operations Analysis                           0.020604
# Persuasion                                    0.000000
# Programming                                  -0.000000
# Quality Control Analysis                      0.000000
# Reading Comprehension                         0.031344
# Repairing                                     0.000000
# Science                                       0.077131
# Service Orientation                           0.000000
# Social Perceptiveness                        -0.148221
# Speaking                                      0.080109
# Systems Analysis                              0.051780
# Systems Evaluation                           -0.085291
# Technology Design                            -0.039390
# Time Management                               0.012133
# Troubleshooting                               0.000000
# Writing                                      -0.034927

# %%
dSummary.reset_index().to_csv(DataDir + 'ScoreAllMeasures_' + interest +'.csv')
