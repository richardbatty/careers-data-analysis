# %% [markdown]
# # Insight Data Science Consulting Project: 80,000 hours - Chapter 5
#
# Note: this is a part of a consulting project with [80,000 hours](https://80000hours.org/).
#
# ## Stage 1: Ask a question
#
# My objective is to rank skills (and possibly knowledge, tools & tech) based on how valuable they are. The skills are listed by US Department of Labor [here](https://www.onetonline.org/find/descriptor/browse/Skills/2.B.1/).
#
# There is no performance measure for this rank yet since it is subjective. Yet in the future, one can create a poll to rate pairwise.
#
# ## Stage 2: Set the environment up and get data
#
# First, set up a directory for data and link it to this workplace. Download data into your choice of directory.

# %%
#Set up the environment
import pandas as pd                        #Pandas
import numpy as np                         #Numpy
import pycurl                              #For saving file from url
import os                                  #For checking if a file exists
from pandas.parser import CParserError     #For checking if a file contains a set of values
import matplotlib.pyplot as plt            #For plotting
import matplotlib
# %matplotlib inline

#Some machine learning tools
from sklearn.linear_model import LassoCV, LassoLarsCV, LinearRegression
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.neural_network import MLPRegressor
from sklearn.model_selection import StratifiedKFold
from sklearn.feature_selection import RFECV

#For radar graph plot
import numpy as np
import matplotlib
import matplotlib.path as path
import matplotlib.pyplot as plt
import matplotlib.patches as patches

# Set up data directory
DataDir = "C:/Users/Admin/Desktop/Insight/data/"
OutputDir = "C:/Users/Admin/Desktop/Insight/output/"

# %%
from bokeh.models import ColumnDataSource, HoverTool, OpenURL, TapTool, Div
from bokeh.plotting import figure, show, output_file
from bokeh.sampledata.periodic_table import elements
from bokeh.io import vplot

from bokeh.layouts import row, widgetbox, layout
from bokeh.models import Select, TextInput
from bokeh.palettes import Spectral5
from bokeh.plotting import curdoc, figure
from bokeh.sampledata.autompg import autompg

from bokeh.embed import components

#make output appeared in notebook
from bokeh.plotting import output_notebook
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="2987e7d7-e846-4867-9dc4-aed4e4d08fc4">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# ## Stage 3+4+5: Feature exploration, scores, and results

# %% [markdown]
# See previous chapter.

# %% [markdown]
# ## Stage 6: Compute score for occupations

# %%
interest = 'Skill'
#interest = 'Knowledge'

# %%
filename = "score_" + interest + ".csv" 
d4dimensions = pd.read_csv(DataDir+ filename)
d4dimensions = d4dimensions.drop('Unnamed: 0', 1)
d4dimensions.rename(columns={'index':interest}, inplace=True)
d4dimensions = d4dimensions.set_index(interest)

# %%
d4dimensions
# Out:
#                                      Income  Satisfaction  Security  \
# Skill
# Active Learning                    2.634182      0.504576  2.069776
# Active Listening                   2.341124      0.428880  2.202526
# Complex Problem Solving            3.147225      0.470851  2.023038
# Coordination                       2.074343      0.447771  2.383270
# Critical Thinking                  3.247886      0.528635  2.325277
# Equipment Maintenance             -0.503275     -0.063316 -0.843287
# Equipment Selection               -0.473784     -0.064737 -0.767879
# Installation                      -0.348337      0.000000 -0.848958
# Instructing                        1.562355      0.378890  1.707986
# Judgment and Decision Making       3.373525      0.547922  2.346067
# Learning Strategies                1.803256      0.438048  1.791882
# Management of Financial Resources  1.792300      0.243484  0.843095
# Management of Material Resources   1.593262      0.271727  1.038333
# Management of Personnel Resources  2.086845      0.362612  1.589367
# Mathematics                        1.725672      0.097368  0.671900
# Monitoring                         2.650519      0.479654  2.287914
# Negotiation                        1.704476      0.288437  1.549052
# Operation Monitoring              -0.338025     -0.057019 -0.509121
# Operation and Control             -0.569528     -0.081749 -0.665054
# Operations Analysis                1.824975      0.261473  0.975697
# Persuasion                         1.839217      0.240179  1.736010
# Programming                        1.835860      0.128721  0.637307
# Quality Control Analysis          -0.000000      0.000000 -0.374090
# Reading Comprehension              2.284322      0.402398  1.661611
# Repairing                         -0.465672     -0.056690 -0.836693
# Science                            1.342842      0.212188  0.498642
# Service Orientation                0.731164      0.166830  1.435044
# Social Perceptiveness              1.534338      0.351174  2.067679
# Speaking                           2.046957      0.395178  2.098110
# Systems Analysis                   2.352932      0.354858  1.499109
# Systems Evaluation                 2.446762      0.356642  1.588392
# Technology Design                  1.958756      0.263648  1.174327
# Time Management                    2.889421      0.513991  2.293531
# Troubleshooting                   -0.368970     -0.049376 -0.653941
# Writing                            1.969658      0.359222  1.474110
#
#                                    Learnability     score     color  \
# Skill
# Active Learning                       -2.341797  0.716684  0.811107
# Active Listening                      -2.322009  0.662630  0.762498
# Complex Problem Solving               -2.354152  0.821741  0.905581
# Coordination                          -1.629980  0.818851  0.902983
# Critical Thinking                     -2.594317  0.876870  0.955158
# Equipment Maintenance                  0.680028 -0.182463  0.002531
# Equipment Selection                    0.654828 -0.162893  0.020129
# Installation                           0.456187 -0.185277  0.000000
# Instructing                           -1.577251  0.517995  0.632432
# Judgment and Decision Making          -2.560573  0.926736  1.000000
# Learning Strategies                   -1.812470  0.555179  0.665870
# Management of Financial Resources     -1.026668  0.463053  0.583024
# Management of Material Resources      -0.946504  0.489205  0.606541
# Management of Personnel Resources     -1.420635  0.654547  0.755229
# Mathematics                           -1.143512  0.337857  0.470439
# Monitoring                            -1.902294  0.878948  0.957026
# Negotiation                           -1.471638  0.517582  0.632060
# Operation Monitoring                   0.724067 -0.045024  0.126125
# Operation and Control                  0.796250 -0.130020  0.049691
# Operations Analysis                   -1.286879  0.443816  0.565725
# Persuasion                            -1.691501  0.530976  0.644105
# Programming                           -1.287573  0.328578  0.462095
# Quality Control Analysis               0.512779  0.034672  0.197794
# Reading Comprehension                 -2.158820  0.547378  0.658855
# Repairing                              0.643004 -0.179013  0.005633
# Science                               -1.008347  0.261331  0.401621
# Service Orientation                   -1.065236  0.316950  0.451638
# Social Perceptiveness                 -1.611079  0.585528  0.693162
# Speaking                              -2.081626  0.614655  0.719355
# Systems Analysis                      -1.819586  0.596828  0.703324
# Systems Evaluation                    -1.860845  0.632738  0.735616
# Technology Design                     -1.195540  0.550298  0.661481
# Time Management                       -2.212556  0.871097  0.949966
# Troubleshooting                        0.670602 -0.100421  0.076308
# Writing                               -1.931696  0.467824  0.587314
#
#                                                      group group_color
# Skill
# Active Learning                                      Basic     #FF0000
# Active Listening                                     Basic     #FF0000
# Complex Problem Solving            Complex Problem Solving     #FFFF00
# Coordination                                        Social     #FFA500
# Critical Thinking                                    Basic     #FF0000
# Equipment Maintenance                            Technical     #008000
# Equipment Selection                              Technical     #008000
# Installation                                     Technical     #008000
# Instructing                                         Social     #FFA500
# Judgment and Decision Making                        System     #800080
# Learning Strategies                                  Basic     #FF0000
# Management of Financial Resources      Resource Management     #0000FF
# Management of Material Resources       Resource Management     #0000FF
# Management of Personnel Resources      Resource Management     #0000FF
# Mathematics                                          Basic     #FF0000
# Monitoring                                           Basic     #FF0000
# Negotiation                                         Social     #FFA500
# Operation Monitoring                             Technical     #008000
# Operation and Control                            Technical     #008000
# Operations Analysis                              Technical     #008000
# Persuasion                                          Social     #FFA500
# Programming                                      Technical     #008000
# Quality Control Analysis                         Technical     #008000
# Reading Comprehension                                Basic     #FF0000
# Repairing                                        Technical     #008000
# Science                                              Basic     #FF0000
# Service Orientation                                 Social     #FFA500
# Social Perceptiveness                               Social     #FFA500
# Speaking                                             Basic     #FF0000
# Systems Analysis                                    System     #800080
# Systems Evaluation                                  System     #800080
# Technology Design                                Technical     #008000
# Time Management                        Resource Management     #0000FF
# Troubleshooting                                  Technical     #008000
# Writing                                              Basic     #FF0000

# %%
l = list(set(d4dimensions['group']))
source = [0]*len(l)

for i in range(0,len(l)):
    source[i] = ColumnDataSource(
                    data=dict(
                        Skill = d4dimensions.index[d4dimensions['group']==l[i]],
                        Income = d4dimensions.loc[d4dimensions['group']==l[i],'Income'],
                        Security = d4dimensions.loc[d4dimensions['group']==l[i],'Security'],
                        Satisfaction = d4dimensions.loc[d4dimensions['group']==l[i],'Satisfaction'],
                        Learnability = d4dimensions.loc[d4dimensions['group']==l[i],'Learnability'],
                        group = d4dimensions.loc[d4dimensions['group']==l[i],'group'],
                        group_color = d4dimensions.loc[d4dimensions['group']==l[i],'group_color'],
                    )
                )

# %%
x_axis = 'Learnability'
y_axis = 'Income'

output_file(x_axis + "_" + y_axis + ".html", title= x_axis + " vs. " + y_axis)

y = d4dimensions[y_axis]
X = d4dimensions[x_axis]

model_ols = LinearRegression(fit_intercept = False).fit(np.matrix(X).T, y)

x_predict = [np.min(X),np.max(X)]
y_predict = model_ols.predict(np.matrix(x_predict).T)

hover = HoverTool(
        tooltips=[
            ("Skill", "@Skill"),
        ]
    )

p = figure(plot_width=600, plot_height=600, tools=[hover], title= x_axis + " vs. " + y_axis)
for i in range(0,len(l)):
    p.circle(x_axis, y_axis, size=20, color = 'group_color', source=source[i], legend=l[i])
p.line(x = x_predict, y = y_predict)
show(p)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="cc24ad4a-cff6-45c5-940d-82873ab28330"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#cc24ad4a-cff6-45c5-940d-82873ab28330").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("cc24ad4a-cff6-45c5-940d-82873ab28330");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'cc24ad4a-cff6-45c5-940d-82873ab28330' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"85728c7f-f16f-4f48-b7b6-c0cf13b7d6ad":{"roots":{"references":[{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":20},"x":{"field":"Learnability"},"y":{"field":"Income"}},"id":"89a19a98-680f-4e3c-9254-5dc6503f882e","type":"Circle"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":20},"x":{"field":"Learnability"},"y":{"field":"Income"}},"id":"594548c2-c6ad-4c66-9fe5-71209d39469c","type":"Circle"},{"attributes":{"plot":null,"text":"Learnability vs. Income"},"id":"b7773dac-2cf6-46d7-a2ef-e7281a881242","type":"Title"},{"attributes":{"below":[{"id":"91aba300-364b-443a-8890-10560afad60a","type":"LinearAxis"}],"left":[{"id":"38fb3924-40b1-45bc-b9e0-4398012a64c9","type":"LinearAxis"}],"renderers":[{"id":"91aba300-364b-443a-8890-10560afad60a","type":"Lin
# %%
x_axis = 'Income'
y_axis = 'Security'

output_file(x_axis + "_" + y_axis + ".html", title= x_axis + " vs. " + y_axis)

y = d4dimensions[y_axis]
X = d4dimensions[x_axis]

model_ols = LinearRegression(fit_intercept = False).fit(np.matrix(X).T, y)

x_predict = [np.min(X),np.max(X)]
y_predict = model_ols.predict(np.matrix(x_predict).T)

hover = HoverTool(
        tooltips=[
            ("Skill", "@Skill"),
        ]
    )

p2 = figure(plot_width=600, plot_height=600, tools=[hover], title= x_axis + " vs. " + y_axis)
for i in range(0,len(l)):
    p2.circle(x_axis, y_axis, size=20, color = 'group_color', source=source[i], legend=l[i])
p2.line(x = x_predict, y = y_predict)
p2.legend.location = "bottom_right"
show(p2);
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="ee96e2a1-e406-45fb-988a-187a03702c31"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#ee96e2a1-e406-45fb-988a-187a03702c31").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("ee96e2a1-e406-45fb-988a-187a03702c31");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'ee96e2a1-e406-45fb-988a-187a03702c31' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"ed6758d4-791c-4ffd-aff6-c5e4092fc8e7":{"roots":{"references":[{"attributes":{"fill_color":{"field":"group_color"},"line_color":{"field":"group_color"},"size":{"units":"screen","value":20},"x":{"field":"Income"},"y":{"field":"Security"}},"id":"385a9003-1278-4e23-8f17-15b9cf9c7c45","type":"Circle"},{"attributes":{},"id":"af1b02a2-643f-4936-99f8-ea06e7a1d063","type":"BasicTickFormatter"},{"attributes":{"data_source":{"id":"1dd220f3-0f1e-4d40-bf0a-5f8b971a2f5a","type":"ColumnDataSource"},"glyph":{"id":"c9368c2d-9f0a-4a24-8ef2-0113132a1771","type":"Circle"},"hover_glyph":null,"nonselection_glyph":{"id":"9a0cdf20-cab7-45fc-8da0-93a948853c12","type":"Circle"},"selection_glyph":null},"id":"aeec86f4-591d-4c3e-8de4-6e561b84379b","type":"GlyphRenderer"},{"attributes":{"fill_color":{"field":"group_color"},"line_color":{"field":"group_color"},"size":{"units":"screen","value":20},"x":{"field":"Income"},"y":{"field":"Security"}},"id":"97068090-1d57-440e-a9ca-75e7393d6963","type":"Circle"},{"attributes":{"callback":null,"column_names":["Satisfaction","Learnability","group_color","group","Income","Security","Skill"],"data":{"Income":[3.14722476703],"Learnability":[-2.3541517293400003],"Satisfaction":[0.470850889772],"Security":[2.0230384155400003],"Skill":["Complex Problem Solving"],"group":["Complex Problem Solving"],"group_color":["#FFFF00"]}},"id":"b936296c-8051-4d5b-bd0c-c3eb177b5fd0","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"d35d9b26-c011-4480-a537-07491c3b0e0c","type":"ColumnDataSource"},"glyph":{"id":"b11f0f64-728a-42dc-a3f4-c27173edba1a","type":"Circle"},"hover_glyph":null,"nonselection_glyph":{"id":"fc2d7f5b-3d5b-4678-83c1-84902deea5c8","type":"Circle"},"selection_glyph":null},"id":"d4e25053-0dc0-4f19-8f3c-ca6fbc6d1d4d","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["Satisfaction","Learnability","group_color","group","Income","Security","Skill"],"data":{"Income":[-0.503274898477,-0.47378366439099995,-0.348336748201,-0.33802470357299996,-0.569528270473,1.8249750004599998,1.83585961969,-0.0,-0.46567182646300004,1.9587562035599997,-0.36896964255500003],"Learnability":[0.6800279391930001,0.654827811905,0.456186820386,0.724067180333,0.796249631637,-1.28687888033,-1.2875730774299998,0.512778979788,0.643004065012,-1.19553969995,0.6706023088040001],"Satisfaction":[-0.0633162483125,-0.0647369645825,0.0,-0.057019147639,-0.081748992783,0.26147272186799997,0.128720536839,0.0,-0.056689944839,0.263648264438,-0.049376472972400005],"Security":[-0.843287463912,-0.7678790961319999,-0.848958216633,-0.5091208204959999,-0.665054008081,0.975697136209,0.6373066070000001,-0.37408971780699996,-0.836692670462,1.17432694174,-0.653941169788],"Skill":["Equipment Maintenance","Equipment Selection","Installation","Operation Monitoring","Operation and Control","Operations Analysis","Programming","Quality Control Analysis","Repairing","Technology Design","Troubleshooting"],"group":["Technical","Technical","Technical","Technical","Technical","Technical","Technical","Technical","Technical","Technical","Technical"],"group_color":["#008000","#008000","#008000","#008000","#008000","#008000","#008000","#008000","#008000","#008000","#008000"]}},"id":"d35d9b26-c011-4480-a537-07491c3b0e0c","type":"ColumnDataSource"},{"attributes":{"fill_color":{"field":"group_color"},"line_color":{"field":"group_color"},"size":{"units":"screen","value":20},"x":{"field":"Income"},"y":{"field":"Security"}},"id":"b11f0f64-728a-42dc-a3f4-c27173edba1a","type":"Circle"},{"attributes":{"callback":null,"column_names":["Satisfaction","Learnability","group_color","group","Income","Security","Skill"],"data":{"Income":[2.63418155452,2.34112419086,3.2478856763099997,1.8032563466799998,1.7256715115,2.6505190125699998,2.28432247915,1.3428415758899999,2.04695654614,1.96965762975],"Learnability":[-2.34179670512,-2.3220092255,-2.59431663545,-1.8124695444,-1.1435123680700001,-1.9022942720599998,-2.15882030444,-1.00834707176,-2.0816256019 ...

# %%
x_axis = 'Income'
y_axis = 'Satisfaction'

output_file(x_axis + "_" + y_axis + ".html", title= x_axis + " vs. " + y_axis)

y = d4dimensions[y_axis]
X = d4dimensions[x_axis]

model_ols = LinearRegression(fit_intercept = False).fit(np.matrix(X).T, y)

x_predict = [np.min(X),np.max(X)]
y_predict = model_ols.predict(np.matrix(x_predict).T)

hover = HoverTool(
        tooltips=[
            ("Skill", "@Skill"),
        ]
    )

p = figure(plot_width=600, plot_height=600, tools=[hover], title= x_axis + " vs. " + y_axis)
for i in range(0,len(l)):
    p.circle(x_axis, y_axis, size=20, color = 'group_color', source=source[i], legend=l[i])
p.line(x = x_predict, y = y_predict)
p.legend.location = "bottom_right"
show(p)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="85087fa1-e461-4a4d-be0e-dcce76ed7b85"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#85087fa1-e461-4a4d-be0e-dcce76ed7b85").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("85087fa1-e461-4a4d-be0e-dcce76ed7b85");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '85087fa1-e461-4a4d-be0e-dcce76ed7b85' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"b8a32cef-fdf0-4647-9d7f-893efd91dc25":{"roots":{"references":[{"attributes":{},"id":"2115fa31-d01b-46e5-add8-112293b536e2","type":"BasicTicker"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":20},"x":{"field":